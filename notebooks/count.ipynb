# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from algorithm.cli.count import main as count_main

# %%
def plot_elapsed_time_over_length(
    lengths: list[int],
    rankings: list[list[tuple[str, list[float]]]],
):
    """
    Plot the elapsed time of each counting method over different string lengths
    using sns lineplot. The x-axis represents the string lengths, and the y-axis represents elapsed time in seconds.
    with 95% confidence intervals. Each method should have a different color and a legend indicating the method names.
    """
    # Prepare data for plotting
    data = []
    for length, ranking in zip(lengths, rankings):
        for method_name, times in ranking:
            for time in times:
                data.append(
                    {
                        "Length": length,
                        "Method": method_name,
                        "Elapsed Time": time,
                    }
                )

    # Create a DataFrame for plotting
    import pandas as pd

    df = pd.DataFrame(data)

    # Plot using seaborn
    plt.figure(figsize=(10, 6))
    sns.lineplot(data=df, x="Length", y="Elapsed Time", hue="Method", marker="o")
    plt.title("Elapsed Time of Counting Methods Over String Lengths")
    plt.xlabel("String Length")
    plt.ylabel("Elapsed Time (seconds)")

    # log log
    plt.xscale("log")
    plt.yscale("log")

    plt.legend(title="Counting Method")
    plt.grid(True)
    plt.show()

# %%
num_iter = 100

lengths = [50, 1e2, 1e3, 1e4, 1e5, 1e6]
elapsed_times = []
for length in lengths:
    results = count_main(
        n_iter=num_iter,
        string_length=int(length),
    )
    elapsed_times.append(results)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[34], line 6
#       4 elapsed_times = []
#       5 for length in lengths:
# ----> 6     results = count_main(
#       7         n_iter=num_iter,
#       8         string_length=int(length),
#       9     )
#      10     elapsed_times.append(results)
#
# File ~/Documents/algorithm/src/algorithm/cli/count.py:37, in main(n_iter, string_length)
#      34 stopwatch = {}
#      36 for _ in range(n_iter):
# ---> 37     s = generate_random_string(string_length)
#      38     for method in count_methods:
#      39         with logger.timer(f"{method.__name__}", verbose=False) as t:
#
# File ~/Documents/algorithm/src/algorithm/data/random.py:6, in generate_random_string(length)
#       4 def generate_random_string(length: int) -> str:
#       5     letters = "abcdefghijklmnopqrstuvwxyz"
# ----> 6     return "".join(random.choice(letters) for _ in range(length))
#
# File ~/Documents/algorithm/src/algorithm/data/random.py:6, in <genexpr>(.0)
#       4 def generate_random_string(length: int) -> str:
#       5     letters = "abcdefghijklmnopqrstuvwxyz"
# ----> 6     return "".join(random.choice(letters) for _ in range(length))
#
# File ~/.local/share/uv/python/cpython-3.12.9-macos-aarch64-none/lib/python3.12/random.py:348, in Random.choice(self, seq)
#     346 if not len(seq):
#     347     raise IndexError('Cannot choose from an empty sequence')
# --> 348 return seq[self._randbelow(len(seq))]
#
# File ~/.local/share/uv/python/cpython-3.12.9-macos-aarch64-none/lib/python3.12/random.py:247, in Random._randbelow_with_getrandbits(self, n)
#     245 getrandbits = self.getrandbits
#     246 k = n.bit_length()
# --> 247 r = getrandbits(k)  # 0 <= r < 2**k
#     248 while r >= n:
#     249     r = getrandbits(k)
#
# KeyboardInterrupt:

# %%
plot_elapsed_time_over_length(
    lengths=lengths,
    rankings=elapsed_times,
)
